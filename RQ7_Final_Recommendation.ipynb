# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dummy decision matrix based on previous results

decision_df = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Decision Tree",
        "Random Forest"
    ],
    "Performance Score": [
        7,
        8,
        9
    ],
    "Interpretability Score": [
        9,
        8,
        7
    ],
    "Deployment Score": [
        9,
        8,
        8
    ]
})

print(decision_df)

decision_df.to_csv(
    "/kaggle/working/RQ7_table.csv",
    index=False
)

# Plot
decision_df.plot(
    x="Model",
    kind="bar"
)

plt.title("RQ7 Final Recommendation Matrix")

plt.tight_layout()

plt.savefig("/kaggle/working/RQ7_figure.pdf")

plt.show()
# Out:
#                  Model  Performance Score  Interpretability Score  \
# 0  Logistic Regression                  7                       9
# 1        Decision Tree                  8                       8
# 2        Random Forest                  9                       7
#
#    Deployment Score
# 0                 9
# 1                 8
# 2                 8
